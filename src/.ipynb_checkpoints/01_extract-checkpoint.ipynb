# %%
# %run utils.ipynb

# %%
import requests
import logging
import os
import json
from datetime import datetime
import time

# --- FUNÇÕES AUXILIARES PARA NOTEBOOK ---
def now_timestamp() -> str:
    """Gera um timestamp formatado."""
    return datetime.now().strftime("%Y%m%d_%H%M%S")

def write_json(data: list, path: str):
    """Salva a lista de dicionários em um arquivo JSON."""
    with open(path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
# ------------------------------------------

# URL da API v2 do Open Brewery DB
API_URL = 'https://api.openbrewerydb.org/v1/breweries'
PER_PAGE = 50  # Máximo permitido por página

# Configura o logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
BASE_PATH = './data_lake' # Definição do path para o ambiente local/Docker

def fetch_breweries():
    """Busca todas as cervejarias da API usando paginação e retorna uma lista de dicionários."""
    all_items, page = [], 1
    
    while True:
        try:
            r = requests.get(API_URL, params={'page': page, 'per_page': PER_PAGE}, timeout=30)
            r.raise_for_status()
            items = r.json()

            if not items:
                logging.info(f'No more data at page {page}. Ending fetch.')
                break

            all_items.extend(items)
            logging.info(f'Fetched page {page} with {len(items)} records')

            # Verifica se é a última página (menos itens que o limite)
            if len(items) < PER_PAGE: 
                logging.info('Last page reached.')
                break
                
            page += 1
            time.sleep(0.5) # Boa prática para evitar sobrecarregar a API

        except requests.RequestException as e:
            logging.error(f'Failed to fetch page {page} - API Error: {e}')
            # No Airflow/Orchestrator, esta seria uma falha com retry.
            break
        except Exception as e:
            logging.exception(f'An unexpected error occurred: {e}')
            break

    logging.info(f'Total records fetched: {len(all_items)}')
    return all_items


def run_extract(output_dir=BASE_PATH):
    """Executa o processo de extração para a Bronze Layer."""
    out_dir = os.path.join(output_dir, 'bronze')
    os.makedirs(out_dir, exist_ok=True)

    # Cria o nome do arquivo com o timestamp
    out_path = os.path.join(out_dir, f'breweries_{now_timestamp()}.json')

    data = fetch_breweries()
    
    if data:
        write_json(data, out_path)
        logging.info(f'Wrote {len(data)} records to {out_path}')
        return out_path
    
    return None

# ---- EXECUÇÃO (Célula 1) ----
bronze_file_path = run_extract()
print(f"\nExtração concluída! Arquivo salvo em: {bronze_file_path}")
# Out:
# 2025-10-21 00:18:17,878 - INFO - Fetched page 1 with 50 records
# 2025-10-21 00:18:18,634 - INFO - Fetched page 2 with 50 records
# 2025-10-21 00:18:20,206 - INFO - Fetched page 3 with 50 records
# 2025-10-21 00:18:25,604 - INFO - Fetched page 4 with 50 records
# 2025-10-21 00:18:27,869 - INFO - Fetched page 5 with 50 records
# 2025-10-21 00:18:29,595 - INFO - Fetched page 6 with 50 records
# 2025-10-21 00:18:33,932 - INFO - Fetched page 7 with 50 records
# 2025-10-21 00:18:40,367 - INFO - Fetched page 8 with 50 records
# 2025-10-21 00:18:44,664 - INFO - Fetched page 9 with 50 records
# 2025-10-21 00:18:47,017 - INFO - Fetched page 10 with 50 records
# 2025-10-21 00:18:49,411 - INFO - Fetched page 11 with 50 records
# 2025-10-21 00:18:50,572 - INFO - Fetched page 12 with 50 records
# 2025-10-21 00:18:52,875 - INFO - Fetched page 13 with 50 records
# 2025-10-21 00:18:57,789 - INFO - Fetched page 14 with 50 records
# 2025-10-21 00:18:59,300 - INFO - Fetched page 15 with 50 records
# 2025-10-21 00:19:00,470 - INFO - Fetched page 16 with 50 records
# 2025-10-21 00:19:01,935 - INFO - Fetched page 17 with 50 records
# 2025-10-21 00:19:02,978 - INFO - Fetched page 18 with 50 records
# 2025-10-21 00:19:04,254 - INFO - Fetched page 19 with 50 records
# 2025-10-21 00:19:05,572 - INFO - Fetched page 20 with 50 records
# 2025-10-21 00:19:06,570 - INFO - Fetched page 21 with 50 records
# 2025-10-21 00:19:07,610 - INFO - Fetched page 22 with 50 records
# 2025-10-21 00:19:08,733 - INFO - Fetched page 23 with 50 records
# 2025-10-21 00:19:11,128 - INFO - Fetched page 24 with 50 records
# 2025-10-21 00:19:12,182 - INFO - Fetched page 25 with 50 records
# 2025-10-21 00:19:13,523 - INFO - Fetched page 26 with 50 records
# 2025-10-21 00:19:14,532 - INFO - Fetched page 27 with 50 records
# 2025-10-21 00:19:15,463 - INFO - Fetched page 28 with 50 records
# 2025-10-21 00:19:16,713 - INFO - Fetched page 29 with 50 records
# 2025-10-21 00:19:18,192 - INFO - Fetched page 30 with 50 records
# 2025-10-21 00:19:24,521 - INFO - Fetched page 31 with 50 records
# 2025-10-21 00:19:28,593 - INFO - Fetched page 32 with 50 records
# 2025-10-21 00:19:29,713 - INFO - Fetched page 33 with 50 records
# 2025-10-21 00:19:31,056 - INFO - Fetched page 34 with 50 records
# 2025-10-21 00:19:32,197 - INFO - Fetched page 35 with 50 records
# 2025-10-21 00:19:33,202 - INFO - Fetched page 36 with 50 records
# 2025-10-21 00:19:37,918 - INFO - Fetched page 37 with 50 records
# 2025-10-21 00:19:40,798 - INFO - Fetched page 38 with 50 records
# 2025-10-21 00:19:43,564 - INFO - Fetched page 39 with 50 records
# 2025-10-21 00:19:45,802 - INFO - Fetched page 40 with 50 records
# 2025-10-21 00:19:47,158 - INFO - Fetched page 41 with 50 records
# 2025-10-21 00:19:48,196 - INFO - Fetched page 42 with 50 records
# 2025-10-21 00:19:49,708 - INFO - Fetched page 43 with 50 records
# 2025-10-21 00:19:51,111 - INFO - Fetched page 44 with 50 records
# 2025-10-21 00:19:52,563 - INFO - Fetched page 45 with 50 records
# 2025-10-21 00:19:53,478 - INFO - Fetched page 46 with 50 records
# 2025-10-21 00:19:54,717 - INFO - Fetched page 47 with 50 records
# 2025-10-21 00:19:55,846 - INFO - Fetched page 48 with 50 records
# 2025-10-21 00:19:57,668 - INFO - Fetched page 49 with 50 records
# 2025-10-21 00:20:01,473 - INFO - Fetched page 50 with 50 records
# 2025-10-21 00:20:03,372 - INFO - Fetched page 51 with 50 records
# 2025-10-21 00:20:04,713 - INFO - Fetched page 52 with 50 records
# 2025-10-21 00:20:05,820 - INFO - Fetched page 53 with 50 records
# 2025-10-21 00:20:06,812 - INFO - Fetched page 54 with 50 records
# 2025-10-21 00:20:08,783 - INFO - Fetched page 55 with 50 records
# 2025-10-21 00:20:10,180 - INFO - Fetched page 56 with 50 records
# 2025-10-21 00:20:11,112 - INFO - Fetched page 57 with 50 records
# 2025-10-21 00:20:12,503 - INFO - Fetched page 58 with 50 records
# 2025-10-21 00:20:13,566 - INFO - Fetched page 59 with 50 records
# 2025-10-21 00:20:14,569 - INFO - Fetched page 60 with 50 records
# 2025-10-21 00:20:16,945 - INFO - Fetched page 61 with 50 records
# 2025-10-21 00:20:19,871 - INFO - Fetched page 62 with 50 records
# 2025-10-21 00:20:22,657 - INFO - Fetched page 63 with 50 records
# 2025-10-21 00:20:24,483 - INFO - Fetched page 64 with 50 records
# 2025-10-21 00:20:27,033 - INFO - Fetched page 65 with 50 records
# 2025-10-21 00:20:35,313 - INFO - Fetched page 66 with 50 records
# 2025-10-21 00:20:40,510 - INFO - Fetched page 67 with 50 records
# 2025-10-21 00:20:42,086 - INFO - Fetched page 68 with 50 records
# 2025-10-21 00:20:43,405 - INFO - Fetched page 69 with 50 records
# 2025-10-21 00:20:46,280 - INFO - Fetched page 70 with 50 records
# 2025-10-21 00:20:48,048 - INFO - Fetched page 71 with 50 records
# 2025-10-21 00:20:56,403 - INFO - Fetched page 72 with 50 records
# 2025-10-21 00:21:04,258 - INFO - Fetched page 73 with 50 records
# 2025-10-21 00:21:06,171 - INFO - Fetched page 74 with 50 records
# 2025-10-21 00:21:07,520 - INFO - Fetched page 75 with 50 records
# 2025-10-21 00:21:09,501 - INFO - Fetched page 76 with 50 records
# 2025-10-21 00:21:10,730 - INFO - Fetched page 77 with 50 records
# 2025-10-21 00:21:11,844 - INFO - Fetched page 78 with 50 records
# 2025-10-21 00:21:12,770 - INFO - Fetched page 79 with 50 records
# 2025-10-21 00:21:13,729 - INFO - Fetched page 80 with 50 records
# 2025-10-21 00:21:14,648 - INFO - Fetched page 81 with 50 records
# 2025-10-21 00:21:15,723 - INFO - Fetched page 82 with 50 records
# 2025-10-21 00:21:17,337 - INFO - Fetched page 83 with 50 records
# 2025-10-21 00:21:18,283 - INFO - Fetched page 84 with 50 records
# 2025-10-21 00:21:19,683 - INFO - Fetched page 85 with 50 records
# 2025-10-21 00:21:23,644 - INFO - Fetched page 86 with 50 records
# 2025-10-21 00:21:24,924 - INFO - Fetched page 87 with 50 records
# 2025-10-21 00:21:26,153 - INFO - Fetched page 88 with 50 records
# 2025-10-21 00:21:27,477 - INFO - Fetched page 89 with 50 records
# 2025-10-21 00:21:29,936 - INFO - Fetched page 90 with 50 records
# 2025-10-21 00:21:30,869 - INFO - Fetched page 91 with 50 records
# 2025-10-21 00:21:32,403 - INFO - Fetched page 92 with 50 records
# 2025-10-21 00:21:33,494 - INFO - Fetched page 93 with 50 records
# 2025-10-21 00:21:34,535 - INFO - Fetched page 94 with 50 records
# 2025-10-21 00:21:35,867 - INFO - Fetched page 95 with 50 records
# 2025-10-21 00:21:37,434 - INFO - Fetched page 96 with 50 records
# 2025-10-21 00:21:38,625 - INFO - Fetched page 97 with 50 records
# 2025-10-21 00:21:39,880 - INFO - Fetched page 98 with 50 records
# 2025-10-21 00:21:40,837 - INFO - Fetched page 99 with 50 records
# 2025-10-21 00:21:45,915 - INFO - Fetched page 100 with 50 records
# 2025-10-21 00:21:51,778 - INFO - Fetched page 101 with 50 records
# 2025-10-21 00:21:54,337 - INFO - Fetched page 102 with 50 records
# 2025-10-21 00:21:55,364 - INFO - Fetched page 103 with 50 records
# 2025-10-21 00:21:57,253 - INFO - Fetched page 104 with 50 records
# 2025-10-21 00:21:58,320 - INFO - Fetched page 105 with 50 records
# 2025-10-21 00:22:01,147 - INFO - Fetched page 106 with 50 records
# 2025-10-21 00:22:02,700 - INFO - Fetched page 107 with 50 records
# 2025-10-21 00:22:05,817 - INFO - Fetched page 108 with 50 records
# 2025-10-21 00:22:07,530 - INFO - Fetched page 109 with 50 records
# 2025-10-21 00:22:11,169 - INFO - Fetched page 110 with 50 records
# 2025-10-21 00:22:13,466 - INFO - Fetched page 111 with 50 records
# 2025-10-21 00:22:14,984 - INFO - Fetched page 112 with 50 records
# 2025-10-21 00:22:16,292 - INFO - Fetched page 113 with 50 records
# 2025-10-21 00:22:20,122 - INFO - Fetched page 114 with 50 records
# 2025-10-21 00:22:21,864 - INFO - Fetched page 115 with 50 records
# 2025-10-21 00:22:23,412 - INFO - Fetched page 116 with 50 records
# 2025-10-21 00:22:24,545 - INFO - Fetched page 117 with 50 records
# 2025-10-21 00:22:25,926 - INFO - Fetched page 118 with 50 records
# 2025-10-21 00:22:27,298 - INFO - Fetched page 119 with 50 records
# 2025-10-21 00:22:28,574 - INFO - Fetched page 120 with 50 records
# 2025-10-21 00:22:30,070 - INFO - Fetched page 121 with 50 records
# 2025-10-21 00:22:31,029 - INFO - Fetched page 122 with 50 records
# 2025-10-21 00:22:32,216 - INFO - Fetched page 123 with 50 records
# 2025-10-21 00:22:33,396 - INFO - Fetched page 124 with 50 records
# 2025-10-21 00:22:34,728 - INFO - Fetched page 125 with 50 records
# 2025-10-21 00:22:40,610 - INFO - Fetched page 126 with 50 records
# 2025-10-21 00:22:42,426 - INFO - Fetched page 127 with 50 records
# 2025-10-21 00:22:43,982 - INFO - Fetched page 128 with 50 records
# 2025-10-21 00:22:45,063 - INFO - Fetched page 129 with 50 records
# 2025-10-21 00:22:46,619 - INFO - Fetched page 130 with 50 records
# 2025-10-21 00:22:48,586 - INFO - Fetched page 131 with 50 records
# 2025-10-21 00:22:50,079 - INFO - Fetched page 132 with 50 records
# 2025-10-21 00:22:51,354 - INFO - Fetched page 133 with 50 records
# 2025-10-21 00:22:52,651 - INFO - Fetched page 134 with 50 records
# 2025-10-21 00:22:53,640 - INFO - Fetched page 135 with 50 records
# 2025-10-21 00:22:55,031 - INFO - Fetched page 136 with 50 records
# 2025-10-21 00:22:56,322 - INFO - Fetched page 137 with 50 records
# 2025-10-21 00:22:57,625 - INFO - Fetched page 138 with 50 records
# 2025-10-21 00:22:58,774 - INFO - Fetched page 139 with 50 records
# 2025-10-21 00:23:01,062 - INFO - Fetched page 140 with 50 records
# 2025-10-21 00:23:02,236 - INFO - Fetched page 141 with 50 records
# 2025-10-21 00:23:03,631 - INFO - Fetched page 142 with 50 records
# 2025-10-21 00:23:06,902 - INFO - Fetched page 143 with 50 records
# 2025-10-21 00:23:07,952 - INFO - Fetched page 144 with 50 records
# 2025-10-21 00:23:09,065 - INFO - Fetched page 145 with 50 records
# 2025-10-21 00:23:09,994 - INFO - Fetched page 146 with 50 records
# 2025-10-21 00:23:11,561 - INFO - Fetched page 147 with 50 records
# 2025-10-21 00:23:12,966 - INFO - Fetched page 148 with 50 records
# 2025-10-21 00:23:14,297 - INFO - Fetched page 149 with 50 records
# 2025-10-21 00:23:15,553 - INFO - Fetched page 150 with 50 records
# 2025-10-21 00:23:16,509 - INFO - Fetched page 151 with 50 records
# 2025-10-21 00:23:17,801 - INFO - Fetched page 152 with 50 records
# 2025-10-21 00:23:19,182 - INFO - Fetched page 153 with 50 records
# 2025-10-21 00:23:20,759 - INFO - Fetched page 154 with 50 records
# 2025-10-21 00:23:22,237 - INFO - Fetched page 155 with 50 records
# 2025-10-21 00:23:23,650 - INFO - Fetched page 156 with 50 records
# 2025-10-21 00:23:24,963 - INFO - Fetched page 157 with 50 records
# 2025-10-21 00:23:26,269 - INFO - Fetched page 158 with 50 records
# 2025-10-21 00:23:27,732 - INFO - Fetched page 159 with 50 records
# 2025-10-21 00:23:29,025 - INFO - Fetched page 160 with 50 records
# 2025-10-21 00:23:30,355 - INFO - Fetched page 161 with 50 records
# 2025-10-21 00:23:31,772 - INFO - Fetched page 162 with 50 records
# 2025-10-21 00:23:33,106 - INFO - Fetched page 163 with 50 records
# 2025-10-21 00:23:35,287 - INFO - Fetched page 164 with 50 records
# 2025-10-21 00:23:36,752 - INFO - Fetched page 165 with 50 records
# 2025-10-21 00:23:38,110 - INFO - Fetched page 166 with 50 records
# 2025-10-21 00:23:39,543 - INFO - Fetched page 167 with 50 records
# 2025-10-21 00:23:41,123 - INFO - Fetched page 168 with 50 records
# 2025-10-21 00:23:42,109 - INFO - Fetched page 169 with 50 records
# 2025-10-21 00:23:43,521 - INFO - Fetched page 170 with 50 records
# 2025-10-21 00:23:44,449 - INFO - Fetched page 171 with 50 records
# 2025-10-21 00:23:47,535 - INFO - Fetched page 172 with 50 records
# 2025-10-21 00:23:49,098 - INFO - Fetched page 173 with 50 records
# 2025-10-21 00:23:50,428 - INFO - Fetched page 174 with 50 records
# 2025-10-21 00:23:51,693 - INFO - Fetched page 175 with 50 records
# 2025-10-21 00:23:53,847 - INFO - Fetched page 176 with 50 records
# 2025-10-21 00:23:54,756 - INFO - Fetched page 177 with 50 records
# 2025-10-21 00:23:56,004 - INFO - Fetched page 178 with 50 records
# 2025-10-21 00:23:57,334 - INFO - Fetched page 179 with 23 records
# 2025-10-21 00:23:57,336 - INFO - Last page reached.
# 2025-10-21 00:23:57,338 - INFO - Total records fetched: 8923
# 2025-10-21 00:23:58,449 - INFO - Wrote 8923 records to ./data_lake/bronze/breweries_20251021_001816.json
# Extração concluída! Arquivo salvo em: ./data_lake/bronze/breweries_20251021_001816.json
